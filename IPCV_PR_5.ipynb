# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash-Yelave/Image_Processing_Computer_Vision/blob/main/IPCV_PR_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/Wolf.jpg', 0)
_, binary = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
kernel = np.ones((5, 5), np.uint8)
erosion = cv2.erode(binary, kernel, iterations=1)
dilation = cv2.dilate(binary, kernel, iterations=1)
opening = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel)
closing = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)
cv2_imshow(img)
cv2_imshow(binary)
cv2_imshow(erosion)
cv2_imshow(dilation)
cv2_imshow(opening)
cv2_imshow(closing)
# Out:
# <PIL.Image.Image image mode=L size=1200x627>
# <PIL.Image.Image image mode=L size=1200x627>
# <PIL.Image.Image image mode=L size=1200x627>
# <PIL.Image.Image image mode=L size=1200x627>
# <PIL.Image.Image image mode=L size=1200x627>
# <PIL.Image.Image image mode=L size=1200x627>
