# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash-Yelave/Image_Processing_Computer_Vision/blob/main/IPCV_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Histogram of Image

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread('/content/ChatGPT Image Apr 1, 2025, 04_31_37 PM.png', cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
plt.hist(img.ravel(),256,[0,256]); plt.show()
plt.imshow(img)
# Out:
# /tmp/ipython-input-2952022148.py:3: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img.ravel(),256,[0,256]); plt.show()

# %% [markdown]
# Filters
