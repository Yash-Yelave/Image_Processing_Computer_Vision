# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash-Yelave/Image_Processing_Computer_Vision/blob/main/IPCV_Test_PR1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/content/drive/MyDrive/Engineering/Sem5/IPCV/PR1/IMG20250728183922.jpg')

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray)

# %%
img = cv2.imread('/content/drive/MyDrive/Engineering/Sem5/IPCV/PR1/IMG20250728183922.jpg')

height, width, channels = img.shape
print(f"Height: {height}, Width: {width}, Channels: {channels}")
# Out:
# Height: 4000, Width: 3000, Channels: 3
